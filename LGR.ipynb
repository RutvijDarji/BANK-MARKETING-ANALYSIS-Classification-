# %%
import pandas as pd

# %%
x_train=pd.read_csv("sx_train.csv")

# %%
x_train.head(2)
# Out:
#    Unnamed: 0       age       job   marital  education  default  housing  \
# 0           0  0.596154  0.636364  0.333333   0.428571      0.0      1.0
# 1           1  0.442308  0.000000  0.333333   0.857143      0.0      1.0
#
#    loan  contact     month  ...  duration  campaign  pdays  previous  \
# 0   1.0      0.0  0.111111  ...  0.423913       0.4    1.0       0.0
# 1   0.0      0.0  0.111111  ...  0.459627       0.6    1.0       0.0
#
#    poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0       0.5           1.0        0.484412       0.615063   0.981410
# 1       0.5           1.0        0.484412       0.615063   0.981864
#
#    nr.employed
# 0          1.0
# 1          1.0
#
# [2 rows x 21 columns]

# %%
y_train=pd.read_csv("sy_train.csv")

# %%
y_train.head(2)
# Out:
#    Unnamed: 0   y
# 0           0  no
# 1           1  no

# %%
y_train.columns
# Out:
# Index(['Unnamed: 0', 'y'], dtype='object')

# %%
y_train=y_train.drop('Unnamed: 0',axis=1)

# %%
y_train.head(2)
# Out:
#     y
# 0  no
# 1  no

# %%
x_test=pd.read_csv("x_test.csv")

# %%
y_test=pd.read_csv("y_test.csv")

# %%
y_test.head(2)
# Out:
#    Unnamed: 0   y
# 0        6796  no
# 1         358  no

# %%
y_test=y_test.drop('Unnamed: 0',axis=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LG=LogisticRegression()

# %%
LG.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
pred=LG.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
LG_acc=round(accuracy_score(pred,y_test)*100,2)

# %%
LG_acc
# Out:
# 72.41
